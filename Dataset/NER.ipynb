# %%
import numpy as np
import pandas as pd
import json

# %%
with open('/content/drive/MyDrive/NLP/Assignment-2/NER_TRAIN_JUDGEMENT.json', 'r') as f:
    df_train = json.load(f)

with open('/content/drive/MyDrive/NLP/Assignment-2/NER_TEST_JUDGEMENT.json', 'r') as f:
    df_test = json.load(f)

# %%
print(df_train[:5])
print(len(df_train))
print(len(df_test))
# Out:
# [{'id': '90d9a97c7b7749ec8a4f460fda6f937e', 'annotations': [{'result': [{'value': {'start': 90, 'end': 103, 'text': 'Hongkong Bank', 'labels': ['ORG']}, 'id': 'C8HPTIM1', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 267, 'end': 278, 'text': 'Rahul & Co.', 'labels': ['ORG']}, 'id': 'KOWE3RAM', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': "\n\n(7) On specific query by the Bench about an entry of Rs. 1,31,37,500 on deposit side of Hongkong Bank account of which a photo copy is appearing at p. 40 of assessee's paper book, learned authorised representative submitted that it was related to loan from broker, Rahul & Co. on the basis of his submission a necessary mark is put by us on that photo copy."}, 'meta': {'source': 'tax_districtcourts judgement https://indiankanoon.org/doc/1556717/'}}, {'id': 'a325c57ba5b84c6fa46bee65e6616633', 'annotations': [{'result': [{'value': {'start': 26, 'end': 30, 'text': 'Agya', 'labels': ['OTHER_PERSON']}, 'id': '0V4Q2F2B', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 101, 'end': 105, 'text': 'Kaur', 'labels': ['OTHER_PERSON']}, 'id': 'HLWY1CM9', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 159, 'end': 174, 'text': 'Tarlochan Singh', 'labels': ['OTHER_PERSON']}, 'id': '9BYYLAZB', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': 'He was also asked whether Agya <span class="hidden_text" id="span_5"> CRA No.326-DB of 1998 6</span> Kaur, mother-in-law of the deceased lived separately from Tarlochan Singh.'}, 'meta': {'source': 'criminal_punjab-haryana_high_court judgement https://indiankanoon.org/doc/264463'}}, {'id': '33cface31108441080976035ee04d07e', 'annotations': [{'result': [{'value': {'start': 13, 'end': 25, 'text': 'Vijay Mishra', 'labels': ['WITNESS']}, 'id': 'F8G5DZ9V', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 44, 'end': 60, 'text': 'HDFC Bank, Noida', 'labels': ['ORG']}, 'id': '6EYWDSH8', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 62, 'end': 64, 'text': 'UP', 'labels': ['GPE']}, 'id': '0CP8SD2M', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 121, 'end': 130, 'text': 'HDFC Bank', 'labels': ['ORG']}, 'id': 'L6YOIRVA', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': ' \n5.2 CW3 Mr Vijay Mishra , Deputy Manager, HDFC Bank, Noida, UP has deposed that complainant had a current account with HDFC Bank in the year 2004\xad2005.'}, 'meta': {'source': 'financial_districtcourts judgement https://indiankanoon.org/doc/94286093/'}}, {'id': '08debe900b51464e9f26b5d1eecae170', 'annotations': [{'result': []}], 'data': {'text': 'You are hereby asked not to carry out any construction work of the said building hereafter since the agreement has been terminated".'}, 'meta': {'source': 'civil_bombay_high_court judgement https://indiankanoon.org/doc/710312'}}, {'id': '428070222cd940eba78b233829eb28b8', 'annotations': [{'result': [{'value': {'start': 18, 'end': 43, 'text': 'T.V. Satyanarayana Murthy', 'labels': ['OTHER_PERSON']}, 'id': 'M7Z8PSX1', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': 'The pillion rider T.V. Satyanarayana Murthy also sustained injuries.'}, 'meta': {'source': 'motorvehicles_andhra_high_court judgement https://indiankanoon.org/doc/903089'}}]
# 9435
# 949

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Splitting Training Data into training and validation sets with an 85:15 ratio

# %%
train_data, val_data = train_test_split(df_train, test_size=0.15, random_state=42)

# %%
print(train_data[:5])
print(len(train_data))
print(val_data[:5])
print(len(val_data))
# Out:
# [{'id': 'b29019e16fc64e5da48f20706b152fae', 'annotations': [{'result': []}], 'data': {'text': 'Therefore, while interpreting statutory provisions, the courts should keep in mind the objectives or purpose for which statute has been enacted.'}, 'meta': {'source': 'tax_kerala_high_court judgement https://indiankanoon.org/doc/1186655'}}, {'id': 'b8f6ac625fb9435db21c94644bf7784f', 'annotations': [{'result': [{'value': {'start': 18, 'end': 38, 'text': 'W.P.No.15821 of 2008', 'labels': ['CASE_NUMBER']}, 'id': 'X6BRP5D2', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 86, 'end': 128, 'text': 'National Rural Employment Guarantee Scheme', 'labels': ['ORG']}, 'id': 'Q2GE2LIK', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': 'The petitioner in W.P.No.15821 of 2008 was never considered for appointment under the National Rural Employment Guarantee Scheme either through Employment Exchange sponsorship or by Outsourcing Agencies.'}, 'meta': {'source': 'industrial&labour_madras_high_court judgement https://indiankanoon.org/doc/1083833'}}, {'id': '4bbb0629e66146edaf4ac7bde47062fb', 'annotations': [{'result': [{'value': {'start': 82, 'end': 100, 'text': 'Sukendra Pal Singh', 'labels': ['OTHER_PERSON']}, 'id': 'NGB7PNGE', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': 'The factum of accident, allegation of rash and negligent driving causing death of Sukendra Pal Singh were denied.'}, 'meta': {'source': 'motorvehicles_districtcourts judgement https://indiankanoon.org/doc/132810052/'}}, {'id': '0373124f0bc54a38ba366718e5dd40eb', 'annotations': [{'result': [{'value': {'start': 10, 'end': 25, 'text': 'W.A.No.655/2012', 'labels': ['CASE_NUMBER']}, 'id': 'B5L3GWC0', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': '..36.. \n\n W.A.No.655/2012 & others Meaning thereby that except interview by the Commission, entire procedure for recruitment as emergency appointment was followed.'}, 'meta': {'source': 'constitution_madhya_pradesh_high_court judgement https://indiankanoon.org/doc/28596677'}}, {'id': '12934312395b4f2cbcf5011d0a9e949e', 'annotations': [{'result': [{'value': {'start': 83, 'end': 95, 'text': 'Evidence Act', 'labels': ['STATUTE']}, 'id': 'HQ2B6U98', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 171, 'end': 183, 'text': 'Evidence Act', 'labels': ['STATUTE']}, 'id': 'OD5MR2W3', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': 'The law on this issue is well settled and the law is that though the provisions of Evidence Act are not applicable, but in a given situation the help of the principles of Evidence Act in the proceedings before the assessing authorities can be taken.'}, 'meta': {'source': 'tax_districtcourts judgement https://indiankanoon.org/doc/511755/'}}]
# 8019
# [{'id': '35a7bbe300734dffae0740ab00356e1d', 'annotations': [{'result': [{'value': {'start': 0, 'end': 35, 'text': 'Clause 18(1), (2) and (3)\n(a) & (b)', 'labels': ['PROVISION']}, 'id': 'TKO7JDET', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 55, 'end': 65, 'text': 'Article 23', 'labels': ['PROVISION']}, 'id': 'YV95YDGK', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 73, 'end': 100, 'text': 'Draft Constitution of India', 'labels': ['STATUTE']}, 'id': 'SPXGPP46', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': 'Clause 18(1), (2) and (3)\n(a) & (b) were transposed in Article 23 of the Draft Constitution of India.'}, 'meta': {'source': 'tax_supremecourts judgement https://indiankanoon.org/doc/512761/'}}, {'id': 'b6d5aee6565043c799ece82bc2b05e43', 'annotations': [{'result': []}], 'data': {'text': 'The order cannot be said to be wrong when the only ground mentioned for impleading the Chief Minister as a party was to make it incumbent on him to file an affidavit, which he was not legally obliged to, if he was not a party.'}, 'meta': {'source': 'land&property_supremecourts judgement https://indiankanoon.org/doc/802267/'}}, {'id': 'e7023716ce814eb28c69e184e2bc8207', 'annotations': [{'result': [{'value': {'start': 0, 'end': 15, 'text': 'Ajit Kumar Guha', 'labels': ['WITNESS']}, 'id': 'HV6KRD9W', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': 'Ajit Kumar Guha (D. W. 1), who was himself a member of the Board, deposed as follows:-- \n "We the members of the Board did not make any separate enquiry.'}, 'meta': {'source': 'tax_calcutta_high_court judgement https://indiankanoon.org/doc/48460'}}, {'id': 'f5d0553584924cd0822bdb0c9db034ce', 'annotations': [{'result': [{'value': {'start': 94, 'end': 106, 'text': 'Lalgopalganj', 'labels': ['GPE']}, 'id': '19T1DTX0', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': 'The purpose of entering into a contract by the petitioner with the ownerof the petrol pump at Lalgopalganj and plying the vehicle 30 kms. off the route every day is definitely for oblique purposes.'}, 'meta': {'source': 'tax_allahabad_high_court judgement https://indiankanoon.org/doc/1073998'}}, {'id': '3e343e171608447f9779565f6fe3c7f9', 'annotations': [{'result': [{'value': {'start': 134, 'end': 143, 'text': 'Dharamvir', 'labels': ['RESPONDENT']}, 'id': 'R1J20BJB', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 159, 'end': 169, 'text': '26.11.2011', 'labels': ['DATE']}, 'id': 'N05J6RPE', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 173, 'end': 183, 'text': '25.11.2012', 'labels': ['DATE']}, 'id': '35C0IG7V', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}, {'value': {'start': 196, 'end': 219, 'text': 'No.0411003111P001471472', 'labels': ['CASE_NUMBER']}, 'id': '6JF26Y09', 'from_name': 'label', 'to_name': 'text', 'type': 'labels'}]}], 'data': {'text': 'It is admitted that the vehicle bearing registration No.DL\xad9CE\xad1188 OMNI EMPI STD was insured with the respondent No.2 in the name of Dharamvir for the period 26.11.2011 to 25.11.2012 vide policy No.0411003111P001471472.'}, 'meta': {'source': 'motorvehicles_districtcourts judgement https://indiankanoon.org/doc/167634807/'}}]
# 1416

# %% [markdown]
# # BIO Encoding + Preprocessing

# %%
def preprocess_data(data):
    preprocessed_data = {}
    for case in data:
        case_id = case['id']
        text = case['data']['text']
        annotations = case['annotations'][0]['result']
        tokens = text.split()
        #print(tokens)
        bio_encoding = ['O']*len(tokens)

        for annotation in annotations:
            label = annotation['value']['labels'][0]
            start = annotation['value']['start']
            end = annotation['value']['end']
            entity = annotation['value']['text']
            entity_tokens = entity.split()
            if(len(entity_tokens) == 1):
                for i in range(len(tokens)):
                    t_470 = tokens[i][1:] if tokens[i].startswith('(') else tokens[i]
                    t_6009 = tokens[i][1:] if tokens[i].startswith('"') else tokens[i]
                    if (tokens[i] == entity or tokens[i][:-1] == entity or tokens[i][:-2] == entity or t_470 == entity or t_6009 == entity) and bio_encoding[i]=='O':
                        bio_encoding[i] = 'B_' + label
                        break
            else:
                for i in range(len(tokens)):
                    t_470 = tokens[i][1:] if tokens[i].startswith('(') else tokens[i]
                    t_6009 = tokens[i][1:] if tokens[i].startswith('"') else tokens[i]
                    if (tokens[i] == entity_tokens[0] or tokens[i][:-1] == entity_tokens[0] or tokens[i][:-2] == entity_tokens[0] or t_470 == entity_tokens[0] or t_6009 == entity_tokens[0]) and bio_encoding[i]=='O':
                        bio_encoding[i] = 'B_' + label
                        for j in range(1, len(entity_tokens)):
                            bio_encoding[i+j] = 'I_' + label
                        break
        #print(bio_encoding)
        preprocessed_data[case_id] = {'text': text, 'labels': bio_encoding}
    return preprocessed_data

# %%
preprocessed_train = preprocess_data(train_data)
for i, (case_id, data) in enumerate(preprocessed_train.items()):
    print(f"Case ID: {case_id}")
    print(f"Text: {data['text']}")
    print(f"Labels: {data['labels']}")
    print()
    if i == 4:
        break
print(len(preprocessed_train))
# Out:
# Case ID: b29019e16fc64e5da48f20706b152fae
# Text: Therefore, while interpreting statutory provisions, the courts should keep in mind the objectives or purpose for which statute has been enacted.
# Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Case ID: b8f6ac625fb9435db21c94644bf7784f
# Text: The petitioner in W.P.No.15821 of 2008 was never considered for appointment under the National Rural Employment Guarantee Scheme either through Employment Exchange sponsorship or by Outsourcing Agencies.
# Labels: ['O', 'O', 'O', 'B_CASE_NUMBER', 'I_CASE_NUMBER', 'I_CASE_NUMBER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_ORG', 'I_ORG', 'I_ORG', 'I_ORG', 'I_ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Case ID: 4bbb0629e66146edaf4ac7bde47062fb
# Text: The factum of accident, allegation of rash and negligent driving causing death of Sukendra Pal Singh were denied.
# Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_OTHER_PERSON', 'I_OTHER_PERSON', 'I_OTHER_PERSON', 'O', 'O']
#
# Case ID: 0373124f0bc54a38ba366718e5dd40eb
# Text: ..36..
#
#  W.A.No.655/2012 & others Meaning thereby that except interview by the Commission, entire procedure for recruitment as emergency appointment was followed.
# Labels: ['O', 'B_CASE_NUMBER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Case ID: 12934312395b4f2cbcf5011d0a9e949e
# Text: The law on this issue is well settled and the law is that though the provisions of Evidence Act are not applicable, but in a given situation the help of the principles of Evidence Act in the proceedings before the assessing authorities can be taken.
# Labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_STATUTE', 'I_STATUTE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_STATUTE', 'I_STATUTE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# 8019

# %%
preprocessed_val = preprocess_data(val_data)
print(preprocessed_val)
print(len(preprocessed_val))
# Out:
# {'35a7bbe300734dffae0740ab00356e1d': {'text': 'Clause 18(1), (2) and (3)\n(a) & (b) were transposed in Article 23 of the Draft Constitution of India.', 'labels': ['B_PROVISION', 'I_PROVISION', 'I_PROVISION', 'I_PROVISION', 'I_PROVISION', 'I_PROVISION', 'I_PROVISION', 'I_PROVISION', 'O', 'O', 'O', 'B_PROVISION', 'I_PROVISION', 'O', 'O', 'B_STATUTE', 'I_STATUTE', 'I_STATUTE', 'I_STATUTE']}, 'b6d5aee6565043c799ece82bc2b05e43': {'text': 'The order cannot be said to be wrong when the only ground mentioned for impleading the Chief Minister as a party was to make it incumbent on him to file an affidavit, which he was not legally obliged to, if he was not a party.', 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, 'e7023716ce814eb28c69e184e2bc8207': {'text': 'Ajit Kumar Guha (D. W. 1), who was himself a member of the Board, deposed as follows:-- \n "We the members of the Board did not make any separate enquiry.', 'labels': ['B_WITNESS', 'I_WITNESS', 'I_WITNESS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, 'f5d0553584924cd0822bdb0c9db034ce': {'text': 'The purpose of entering into a contract by the petitioner with the ownerof the petrol pump at Lalgopalganj and plying the vehicle 30 kms. off the route every day is definitely for oblique purposes.', 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, '3e343e171608447f9779565f6fe3c7f9': {'text': 'It is admitted that the vehicle bearing registration No.DL\xad9CE\xad1188 OMNI EMPI STD was insured with the respondent No.2 in the name of Dharamvir for the period 26.11.2011 to 25.11.2012 vide policy No.0411003111P001471472.', 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_RESPONDENT', 'O', 'O', 'O', 'B_DATE', 'O', 'B_DATE', 'O', 'O', 'B_CASE_NUMBER']}, 'a3bdbcf71169456aa96703c9fe99c1a9': {'text': 'A vehicle was arranged and the dead body was sent for postmortem examination.', 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, 'b2275fdf7b4d4cf1997853ec7d1c7525': {'text': '4. Under Schedule I of the Calcutta Municipal Act, 1923, as also in Schedule I of the Calcutta Municipal Act, 1951 (hereinafter referred to as the \'Act\') as originally enacted, "Calcutta" has been defined.', 'labels': ['O', 'O', 'B_PROVISION', 'I_PROVISION', 'O', 'O', 'B_STATUTE', 'I_STATUTE', 'I_STATUTE', 'I_STATUTE', 'O', 'O', 'O', 'B_PROVISION', 'I_PROVISION', 'O', 'O', 'B_STATUTE', 'I_STATUTE', 'I_STATUTE', 'I_STATUTE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, '442ff211d0c54d649ca527ffd8092c0b': {'text': 'Learned Deputy Advocate General, Haryana has submitted, on the other hand, that learned trial court has made a fair Crl.Appeal No.374-DB of 2002 .... \n\n assessment of the evidence coming from both the sides.', 'labels': ['O', 'O', 'O', 'O', 'B_GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_CASE_NUMBER', 'I_CASE_NUMBER', 'I_CASE_NUMBER', 'I_CASE_NUMBER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, 'c068f050d5fd4114a185841b1d990063': {'text': 'Issacs, J. observed as follows:-\n "There can be no question that the Commonwealth Navigation Act, by its own direct provisions and the Regulations made under its authority, applies upon construction to the circumstances of the case.', 'labels': ['B_JUDGE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_STATUTE', 'I_STATUTE', 'I_STATUTE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, 'ec48abc3930a4a9e865b9c880490d2f1': {'text': "Mr. Mitra  ...
# 1416

# %%
preprocessed_test = preprocess_data(df_test)
print(preprocessed_test)
print(len(preprocessed_test))
# Out:
# {'03f3901e95ed493b866bd7807f623bc0': {'text': "True, our Constitution has no 'due process' clause or the VIII Amendment; but, in this branch of law, after R.C. Cooper v. Union of India, (1970) 1 SCC 248 and Maneka Gandhi v. Union of India, (1978) 1 SCC 248, the consequence is the same.", 'labels': ['O', 'O', 'B_STATUTE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'O', 'B_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'I_PRECEDENT', 'O', 'O', 'O', 'O', 'O']}, 'b0311cba3aac4d909eec6e156c059617': {'text': '(See Principles of Statutory Interpretation by Justice G.P. Singh, 9th Edn., 2004 at p. \n\n 438.).', 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_JUDGE', 'I_JUDGE', 'O', 'O', 'O', 'O', 'O', 'O']}, '0215658407ec479fa4e0e73ca0bf98b6': {'text': 'Their Lordships have said --  "It is a sound rule of construction of a statute firmly established in England as far back as 1584 when Heydon\'s case was decided that --"......', 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'B_OTHER_PERSON', 'O', 'O', 'O', 'O', 'O']}, 'cf44f4898b67493390f1a8c8c7dfc0cc': {'text': 'In para 13 of the plaint, it has been further averred that, "When the plaintiffs asked the defendant to obtain requisite documents immediately, the defendant assured the plaintiffs that he would obtain the requisite documents and would be available on 29/12/2004 at the office of the Sub\xadRegistrar, Geeta Colony, Delhi and would execute the sale deed".', 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_DATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_GPE', 'O', 'O', 'O', 'O', 'O', 'O']}, 'f16b5b960a854b18bf171b4cff9b5b11': {'text': "Counsel for appellants contended that who is the Jagirdar against whom the legal fiction is to apply, is not pleaded by the claim petitioners and the scope and ambit of Rule 2 of the Rules regarding 'Grant of Pattadari rights in non-Khalsa villages', 1356 Fasli framed under Section 172 of the Hyderabad Land Revenue Act, 1317 Fasli is nebulous.", 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_PROVISION', 'I_PROVISION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_PROVISION', 'I_PROVISION', 'O', 'O', 'B_STATUTE', 'I_STATUTE', 'I_STATUTE', 'I_STATUTE', 'I_STATUTE', 'O', 'O', 'O']}, '77f51488c3974abd96582e255f3bf784': {'text': 'Further, section 19(3) of the SG Act specifies that unless a different intention appears, rules contained in section 20 to 24 rules for ascertaining the intention of the parties as to the time at which the property and goods is to passed to the buyer.', 'labels': ['O', 'B_PROVISION', 'I_PROVISION', 'O', 'O', 'B_STATUTE', 'I_STATUTE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_PROVISION', 'I_PROVISION', 'I_PROVISION', 'I_PROVISION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, 'fefa6345325e4653ae198bcf12e493d5': {'text': 'Hence, the Trial Court convicted the Appellant under Section 13(2) read with Section 13(1)(e) of the PC Act; as well as Sections 120B and 193 of the IPC, and sentenced him to rigorous imprisonment for two years and payment of fine of Rs 1.5 lakhs.', 'labels': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_PROVISION', 'I_PROVISION', 'O', 'O', 'B_PROVISION', 'I_PROVISION', 'O', 'O', 'B_STATUTE', 'I_STATUTE', 'O', 'O', 'O', 'B_PROVISION', 'I_PROVISION', 'I_PROVI ...
# 949

# %%
with open('/content/drive/MyDrive/NLP/Assignment-2/NER_train.json', 'w') as f:
    json.dump(preprocessed_train, f)

with open('/content/drive/MyDrive/NLP/Assignment-2/NER_val.json', 'w') as f:
    json.dump(preprocessed_val, f)

with open('/content/drive/MyDrive/NLP/Assignment-2/NER_test.json', 'w') as f:
    json.dump(preprocessed_test, f)
